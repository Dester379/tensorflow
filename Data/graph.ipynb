# %%
import pandas as pd
import numpy as np
import networkx as nx
from networkx import *
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
location='выборка.xlsx'
df=pd.read_excel(location)
df.columns=['N','u1','u2']

# %%
G.add_nodes_from(df.u1)

# %%
import pydot

# %%
G=nx.from_pandas_dataframe(df, 'u1','u2')

# %%
G=nx.cubical_graph()
nx.draw(G)   # тип по умолчанию spring_layout
nx.draw(G,pos=nx.spectral_layout(G), nodecolor='r',edge_color='b')

# %%
nx.draw(G,nx.spring_layout(G), node_size=50,edge_color='b')

# %%
G=nx.Graph()
G.add_nodes_from([1,2,3,8], size=0.1)

# %%
nx.draw_circular(G, node_size=50,edge_size=3)

# %%
nodes=nx.draw_networkx_nodes(G,pos=nx.spring_layout(G), node_size=30)
edges=nx.draw_networkx_edges(G,pos=nx.spring_layout(G))

# %%
K=complete_graph(5)
nodes=nx.draw_networkx_nodes(K,pos=nx.spring_layout(K), node_size=300)
nodes2=nx.draw_networkx_edges(K,pos=nx.spring_layout(K), node_size=300)
labels=nx.draw_networkx_labels(K,nx.spring_layout(K))

# %%
G.add_edge(123,224)
G.add_edge(123,24)
G.add_edge(13,242)
G.add_edge(1,24)

# %%
G.add_edges_from(tuples)

# %%
tuple(pd.concat([df.u1, df.u2], axis=1))
# Out:
# ('u1', 'u2')

# %%
subset = df[['u1', 'u2']]

# %%
tuples = [tuple(x) for x in subset.values]

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
df1 = pd.concat([df.u1, df.u2])
label.fit(df1)
df.u1 = label.transform(df.u1)
df.u2 = label.transform(df.u2)
